# %%
from sklearn.cluster import KMeans
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import tree

from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Conhecendo os dados

# %%
df = pd.read_csv('data/Mall_Customers.csv', names=["id", "genero", "idade", "receita", 'score'],  skiprows=[0])

# %%
df.head()
# Out:
#    id  genero  idade  receita  score
# 0   1    Male     19       15     39
# 1   2    Male     21       15     81
# 2   3  Female     20       16      6
# 3   4  Female     23       16     77
# 4   5  Female     31       17     40

# %%
df.count()
# Out:
# id         200
# genero     200
# idade      200
# receita    200
# score      200
# dtype: int64

# %%
sns.scatterplot(data=df, x="score", y="idade")
# Out:
# <AxesSubplot:xlabel='score', ylabel='idade'>

# %%
dk = df[["score", "idade"]]
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(dk)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeanModel = KMeans(n_clusters=3)
kmeanModel.fit(dk)
# Out:
# KMeans(n_clusters=3)

# %%
df['perfil']=kmeanModel.predict(dk)

# %%
sns.scatterplot(data=df, x="score", y="idade", hue="perfil")
# Out:
# <AxesSubplot:xlabel='score', ylabel='idade'>

# %%
clf = DecisionTreeClassifier(random_state=0)
X, y  = df[["score", "idade", "receita"]], df[["perfil"]]
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, feature_names=["score", "idade", "receita"], filled=True, class_names=["perfil 1", "perfil 2", "perfil 3"])
